# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time

headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}

# %%
main_webUrl = "https://www.rumah123.com/jual/banten/rumah/?page=1"

req_main = requests.get(main_webUrl, headers=headers)

# %%
main_html = BeautifulSoup(req_main.content, "html5lib")

# %%
max_page = main_html.find_all("li", attrs={"class": "ui-molecule-paginate__item"})
max_page = int(max_page[-1].text)
max_page
# Out:
# 2500

# %%
dataframe = {}
dataframe["Nama"] = []
dataframe["Harga"] = []

# %%
for i in range(1,200):
    webUrl = f"https://www.rumah123.com/jual/banten/rumah/?page={i}"
    req = requests.get(webUrl, headers=headers)
    
    html = BeautifulSoup(req.content, "html5lib")
    time.sleep(2)
    
    link_sections = html.find_all("div", attrs={"class" : "intersection-card-container"})

    for link_sec in link_sections:
        link = link_sec.find("h2").parent["href"]
        
        if "perumahan-baru" in link:
            continue
        try:
            sub_url = requests.get("https://www.rumah123.com" + link, headers=headers)
            sub_html = BeautifulSoup(sub_url.content, "html5lib")
            time.sleep(2)

            title = sub_html.find("h1", attrs={"class" :"text-gray-800 text mb-5"})
            dataframe["Nama"].append(title.text)
            
            specific_div = sub_html.find("div", attrs={"class" : "w-full md:w-[750px] self-stretch"})
            harga = specific_div.find("span")
            dataframe["Harga"].append(harga.text)

            property_div = sub_html.find("div",attrs={"id" : "property-information"})

            propertyes = [[prob.text,prob.nextSibling.text] for prob in property_div.find_all("p", attrs={"class":"w-32"})]
        except:
            continue
        
        print(link)
        for prop in propertyes:
            prop_key = prop[0]
            prop_value = prop[1]
            
            if not prop_key in dataframe.keys():
                dataframe[prop_key] = []
            
            if prop_key in dataframe.keys():
                dataframe[prop_key].append(prop_value)
            
        print("")
# Out:
# /properti/tangerang-selatan/hos18959341/
#
# /properti/tangerang/hos18547416/
#
# /properti/tangerang-selatan/hos18016484/
#
# /properti/tangerang-selatan/hos19199308/
#
# /properti/tangerang-selatan/hos18893778/
#
# /properti/tangerang-selatan/hos18564825/
#
# /properti/tangerang/hos18547428/
#
# /properti/tangerang-selatan/hos16619370/
#
# /properti/tangerang-selatan/hos18382596/
#
# /properti/tangerang-selatan/hos18242999/
#
# /properti/tangerang-selatan/hos17302890/
#
# /properti/tangerang/hos18579166/
#
# /properti/tangerang-selatan/hos18382576/
#
# /properti/tangerang/hos18033532/
#
# /properti/tangerang-selatan/hos15879031/
#
# /properti/tangerang/hos18293236/
#
# /properti/tangerang/hos18847936/
#
# /properti/tangerang/hos17677082/
#
# /properti/tangerang-selatan/hos17958108/
#
# /properti/tangerang/hos19228136/
#
# /properti/tangerang/hos17333098/
#
# /properti/tangerang/hos19163463/
#
# /properti/tangerang/hos15826940/
#
# /properti/tangerang/hos19262487/
#
# /properti/tangerang/hos18225060/
#
# /properti/tangerang/hos19204064/
#
# /properti/tangerang/hos19202844/
#
# /properti/tangerang/hos18477605/
#
# /properti/tangerang/hos16304546/
#
# /properti/tangerang/hos19369864/
#
# /properti/tangerang/hos19369806/
#
# /properti/tangerang-selatan/hos18974654/
#
# /properti/tangerang/hos19358744/
#
# /properti/tangerang-selatan/hos18842764/
#
# /properti/tangerang/hos17443378/
#
# /properti/tangerang/hos13316935/
#
# /properti/tangerang/hos18584008/
#
# /properti/tangerang/hos19064785/
#
# /properti/tangerang-selatan/hos19270609/
#
# /properti/tangerang/hos19366390/
#
# /properti/tangerang-selatan/hos18579162/
#
# /properti/tangerang/hos16833349/
#
# /properti/tangerang-selatan/hos18493948/
#
# /properti/tangerang-selatan/hos19255851/
#
# /properti/tangerang-selatan/hos17285790/
#
# /properti/tangerang/hos18181274/
#
# /properti/tangerang-selatan/hos15674982/
#
# /properti/tangerang/hos18072017/
#
# /properti/tangerang-selatan/hos18573894/
#
# /properti/tangerang/hos18450957/
#
# /properti/tangerang/hos18987966/
#
# /properti/tangerang/hos19311395/
#
# /properti/tangerang/hos18074437/
#
# /properti/tangerang/hos19311339/
#
# /properti/tangerang/hos16886333/
#
# /properti/tangerang-selatan/hos18905876/
#
# /properti/tangerang/hos16667312/
#
# /properti/tangerang/hos18139851/
#
# /properti/tangerang-selatan/hos18269682/
#
# /properti/tangerang-selatan/hos18370263/
#
# /properti/tangerang-selatan/hos18647038/
#
# /properti/tangerang/hos18573890/
#
# /properti/tangerang-selatan/hos18564063/
#
# /properti/tangerang/hos16595623/
#
# /properti/tangerang/hos16708427/
#
# /properti/tangerang-selatan/hos13410732/
#
# /properti/tangerang/hos14782663/
#
# /properti/tangerang/hos13434033/
#
# /properti/tangerang-selatan/hos18284073/
#
# /properti/tangerang-selatan/hos18334679/
#
# /properti/tangerang-selatan/hos12999523/
#
# /properti/tangerang/hos18365409/
#
# /properti/tangerang/hos18392136/
#
# /properti/tangerang/hos18581778/
#
# /properti/tangerang/hos10065492/
#
# /properti/tangerang/hos10740225/
#
# /properti/tangerang-selatan/hos18702906/
#
# /properti/tangerang-selatan/hos18704214/
#
# /properti/tangerang/hos10163275/
#
# /properti/tangerang-selatan/hos18284075/
#
# /properti/tangerang-selatan/hos18284074/
#
# /properti/tangerang/hos18697319/
#
# /properti/tangerang/hos19307480/
#
# /properti/tangerang/hos19306390/
#
# /properti/tangerang-selatan/hos17463564/
#
# /properti/tangerang-selatan/hos18867037/
#
# /properti/tangerang/hos19261385/
#
# /properti/tangerang/hos19302921/
#
# /properti/tangerang-selatan/hos19020024/
#
# /properti/tangerang/hos19086213/
#
# /properti/tangerang/hos19256352/
#
# /properti/tangerang/hos19255094/
#
# /properti/tangerang-selatan/hos19251785/
#
# /properti/tangerang-selatan/hos18575924/
#
# /properti/tangerang-selatan/hos18279933/
#
# /properti/tangerang/hos18920306/
#
# /properti/tangerang/hos18066115/
#
# /properti/tangerang-selatan/hos18431310/
#
# /properti/tangerang-selatan/hos17987197/
#
# /properti/tangerang-selatan/hos19199152/
#
# /properti/tangerang-selatan/hos15775809/
#
# /properti/tangerang/hos19113623/
#
# /properti/tangerang-selatan/hos18271233/
#
# /properti/tangerang/hos19011711/
#
# /properti/tangerang/hos18123972/
#
# /properti/tangerang/hos18538553/
#
# /properti/tangerang-selatan/hos17989030/
#
# /properti/tangerang/hos17275933/
#
# /properti/tangerang/hos19011738/
#
# /properti/tangerang-selatan/hos17480257/
#
# /properti/tangerang-selatan/hos17962123/
#
# /properti/tangerang/hos18181265/
#
# /properti/tangerang-selatan/hos18181244/
#
# /properti/tangerang/hos18917953/
#
# /properti/tangerang/hos18066095/
#
# /properti/tangerang-selatan/hos17875458/
#
# /properti/tangerang-selatan/hos18550591/
#
# /properti/tangerang/hos16662806/
#
# /properti/tangerang/hos18854611/
#
# /properti/tangerang-selatan/hos17083467/
#
# /properti/tangerang-selatan/hos18564476/
#
# /properti/tangerang-selatan/hos18575923/
#
# /properti/tangerang-selatan/hos18493955/
#
# /properti/tangerang/hos18647042/
#
# /properti/tangerang-selatan/hos18033538/
#
# /properti/tangerang/hos18987274/
#
# /properti/tangerang-selatan/hos18915919/
#
# /properti/tangerang/hos18919718/
#
# /properti/tangerang-selatan/hos18642028/
#
# /properti/tangerang/hos18905296/
#
# /properti/tangerang/hos19011723/
#
# /properti/tangerang-selatan/hos18224745/
#
# /properti/tangerang/hos19011735/
#
# /properti/tangerang-selatan/hos18035332/
#
# /properti/tangerang-selatan/hos18271216/
#
# /properti/tangerang-selatan/hos18421483/
#
# /properti/tangerang/hos19240945/
#
# /properti/tangerang/hos18895211/
#
# /properti/tangerang-selatan/hos18446737/
#
# /properti/tangerang-selatan/hos19134087/
#
# /properti/tangerang-selatan/hos18347380/
#
# /properti/tangerang-selatan/hos16283649/
#
# /properti/tangerang-selatan/hos18564544/
#
# /properti/tangerang/hos18304573/
#
# /properti/tangerang/hos19134111/
#
# /properti/tangerang/hos18457302/
#
# /properti/tangerang-selatan/hos18518575/
#
# /properti/tangerang-selatan/hos15778041/
#
# /properti/tangerang/hos16390021/
#
# /properti/tangerang-selatan/hos18919716/
#
# /properti/tangerang/hos18518595/
#
# /properti/tangerang/hos18919699/
#
# /properti/tangerang/hos18271447/
#
# /properti/tangerang/hos18854664/
#
# /properti/tangerang/hos16712608/
#
# /properti/tangerang/hos15791900/
#
# /properti/tangerang-selatan/hos18224711/
#
# /properti/tangerang/hos18181268/
#
# /properti/tangerang/hos16673277/
#
# /properti/tangerang-selatan/hos18896957/
#
# /properti/tangerang/hos18181281/
#
# /properti/tangerang/hos16702386/
#
# /properti/tangerang/hos17997387/
#
# /properti/tangerang-selatan/hos16781260/
#
# /properti/tangerang/hos18181322/
#
# /properti/tangerang-selatan/hos18058670/
#
# /properti/tangerang-selatan/hos17988750/
#
# /properti/tangerang/hos18279855/
#
# /properti/tangerang-selatan/hos18539190/
#
# /properti/tangerang-selatan/hos18066083/
#
# /properti/tangerang-selatan/hos18058712/
#
# /properti/tangerang-selatan/hos18855260/
#
# /properti/tangerang-selatan/hos18539204/
#
# /properti/tangerang/hos17050845/
#
# /properti/tangerang-selatan/hos18271342/
#
# /properti/tangerang-selatan/hos18480475/
#
# /properti/tangerang/hos16965287/
#
# /properti/tangerang/hos18181315/
#
# /properti/tangerang/hos18347374/
#
# /properti/tangerang-selatan/hos17285783/
#
# /properti/tangerang/hos17228677/
#
# /properti/tangerang/hos18181311/
#
# /properti/tangerang/hos16619507/
#
# /properti/tangerang-selatan/hos18279878/
#
# /properti/tangerang-selatan/hos18243018/
#
# /properti/tangerang-selatan/hos18062066/
#
# /properti/tangerang/hos17997200/
#
# /properti/tangerang-selatan/hos18306470/
#
# /properti/tangerang/hos18043312/
#
# /properti/tangerang/hos18854915/
#
# /properti/tangerang/hos18412184/
#
# /properti/tangerang-selatan/hos18646972/
#
# /properti/tangerang-selatan/hos17962221/
#
# /properti/tangerang-selatan/hos18304450/
#
# /properti/tangerang/hos18538721/
#
# /properti/tangerang-selatan/hos18413816/
#
# /properti/tangerang/hos17875605/
#
# /properti/tangerang-selatan/hos18890552/
#
# /properti/tangerang-selatan/hos18410066/
#
# /properti/tangerang/hos18303018/
#
# /properti/tangerang/hos18457332/
#
# /properti/tangerang-selatan/hos18279929/
#
# /properti/tangerang/hos12345070/
#
# /properti/tangerang/hos19226858/
#
# /properti/tangerang-selatan/hos18869717/
#
# /properti/tangerang/hos17087375/
#
# /properti/tangerang/hos16634180/
#
# /properti/tangerang/hos18663556/
#
# /properti/tangerang/hos19250365/
#
# /properti/tangerang/hos19248724/
#
# /properti/tangerang-selatan/hos19177699/
#
# /properti/tangerang/hos18659910/
#
# /properti/tangerang/hos14537011/
#
# /properti/tangerang/hos18855783/
#
# /properti/tangerang/hos19193030/
#
# /properti/tangerang/hos19198033/
#
# /properti/tangerang/hos11400980/
#
# /properti/tangerang/hos19128931/
#
# /properti/tangerang-selatan/hos18025892/
#
# /properti/tangerang-selatan/hos18619062/
#
# /properti/tangerang-selatan/hos18297238/
#
# /properti/tangerang-selatan/hos18137747/
#
# /properti/tangerang/hos18217020/
#
# /properti/tangerang/hos19071153/
#
# /properti/tangerang/hos19192896/
#
# /properti/tangerang/hos17892445/
#
# /properti/tangerang/hos19191823/
#
# /properti/tangerang/hos19047987/
#
# /properti/tangerang/hos18973059/
#
# /properti/tangerang/hos18853700/
#
# /properti/tangerang/hos18853699/
#
# /properti/tangerang-selatan/hos18888804/
#
# /properti/tangerang/hos18888795/
#
# /properti/tangerang-selatan/hos18836578/
#
# /properti/tangerang/hos19284363/
#
# /properti/tangerang/hos19355569/
#
# /properti/tangerang/hos15307435/
#
# /properti/tangerang-selatan/hos19355069/
#
# /properti/tangerang-selatan/hos13986563/
#
# /properti/tangerang-selatan/hos13916534/
#
# /properti/tangerang/hos19354060/
#
# /properti/tangerang/hos19353951/
#
# /properti/tangerang/hos19349050/
#
# /properti/tangerang-selatan/hos18136433/
#
# /properti/tangerang/hos19301243/
#
# /properti/tangerang-selatan/hos18602706/
#
# /properti/tangerang/hos19300327/
#
# /properti/tangerang-selatan/hos19244184/
#
# /properti/tangerang-selatan/hos18183004/
#
# /properti/tangerang/hos17048488/
#
# /properti/tangerang/hos18146549/
#
# /properti/tangerang/hos19272046/
#
# /properti/tangerang/hos19243981/
#
# /properti/tangerang/hos14956279/
#
# /properti/tangerang/hos19151013/
#
# /properti/tangerang/hos19243282/
#
# /properti/tangerang-selatan/hos19242675/
#
# /properti/tangerang/hos18351376/
#
# /properti/serang/hos18121347/
#
# /properti/serang/hos18241554/
#
# /properti/tangerang-selatan/hos18204270/
#
# /properti/tangerang/hos19189029/
#
# /properti/tangerang/hos19168796/
#
# /properti/cilegon/hos18268151/
#
# /properti/tangerang-selatan/hos15803463/
#
# /properti/tangerang/hos18225368/
#
# /properti/tangerang/hos18695081/
#
# /properti/tangerang/hos18140842/
#
# /properti/tangerang-selatan/hos19219507/
#
# /properti/tangerang/hos19344428/
#
# /properti/tangerang/hos19189516/
#
# /properti/tangerang/hos19253201/
#
# /properti/tangerang/hos19198419/
#
# /properti/tangerang-selatan/hos16935593/
#
# /properti/tangerang/hos18974690/
#
# /properti/tangerang/hos19040197/
#
# /properti/tangerang/hos19172906/
#
# /properti/tangerang/hos17968964/
#
# /properti/tangerang-selatan/hos19279787/
#
# /properti/tangerang-selatan/hos19302400/
#
# /properti/tangerang-selatan/hos19359677/
#
# /properti/tangerang-selatan/hos19255089/
#
# /properti/tangerang-selatan/hos19328164/
#
# /properti/tangerang/hos19190771/
#
# /properti/tangerang-selatan/hos18136120/
#
# /properti/tangerang/hos19358194/
#
# /properti/tangerang/hos17144413/
#
# /properti/tangerang-selatan/hos18597391/
#
# /properti/tangerang/hos18827437/
#
# /properti/tangerang-selatan/hos19356608/
#
# /properti/tangerang/hos19263185/
#
# /properti/tangerang-selatan/hos19074083/
#
# /properti/tangerang-selatan/hos16517894/
#
# /properti/tangerang/hos19199757/
#
# /properti/tangerang-selatan/hos19388822/
#
# /properti/tangerang-selatan/hos18981482/
#
# /properti/tangerang/hos18245543/
#
# /properti/tangerang/hos18270943/
#
# /properti/tangerang/hos19390660/
#
# /properti/tangerang/hos19098353/
#
# /properti/tangerang/hos19347041/
#
# /properti/tangerang/hos19338247/
#
# /properti/tangerang-selatan/hos19342144/
#
# /properti/tangerang/hos14385061/
#
# /properti/tangerang/hos18783543/
#
# /properti/tangerang/hos19179086/
#
# /properti/tangerang/hos19179051/
#
# /properti/tangerang-selatan/hos18191859/
#
# /properti/tangerang/hos18302075/
#
# /properti/pandeglang/hos19344509/
#
# /properti/tangerang/hos19073418/
#
# /properti/tangerang-selatan/hos16590551/

# %%
rumah123_df = pd.DataFrame.from_dict(dataframe, orient='index').T
rumah123_df = rumah123_df.fillna(0)
rumah123_df.to_json("Provinsi_Banten.json", orient="records")

# %%
rumah123_df
# Out:
#                                                   Nama           Harga  \
# 0    Dijual Rumah LT 180 Asri di Pamulang 8 Menit k...  Rp 1,77 Miliar
# 1    Rumah Hadap Utara di Jalan Luas dekat Lippo Ka...     Rp 670 Juta
# 2    Rumah 2 KT Free Renov 15 Mnt ke Pintu Tol Pamu...  Rp 1,08 Miliar
# 3    Rumah Strategis LT 792 dekat Bintaro Jaya Xcha...  Rp 12,7 Miliar
# 4    Rumah Strategis LT 133 Bisa Nego 10 Menit ke P...  Rp 1,66 Miliar
# ..                                                 ...             ...
# 307  Dijual Rumah Favorit Keluarga, 4+1 Kamar Tidur...  Rp 1,66 Miliar
# 308  Rumah Baru 2 Lantai ala Jepang Strategis di Bs...     Rp 3 Miliar
# 309  Dijual Rumah Bagus Dan Terawat View Pegunungan...   Rp 1,8 Miliar
# 310  Dijual Cepat Rumah 1 Lantai Abira Suvarna Sute...     Rp 1 Miliar
# 311  Rumah di Discovery Bintaro, Sdh Renov Dan Siap...  Rp 3,55 Miliar
#
#     Kamar Tidur Kamar Mandi Luas Tanah Luas Bangunan Sertifikat Daya Listrik  \
# 0             5           3     180 m²        180 m²        SHM    2200 Watt
# 1             2           1      60 m²         50 m²        SHM     900 Watt
# 2             2           1      90 m²         55 m²        SHM      Lainnya
# 3            10          10     792 m²        400 m²        SHM      Lainnya
# 4             2           2     133 m²        100 m²        SHM    2200 Watt
# ..          ...         ...        ...           ...        ...          ...
# 307           6           4      90 m²        125 m²        SHM    2200 Watt
# 308           4           3      98 m²        118 m²    Lainnya    2200 Watt
# 309           0           0     365 m²        500 m²        SHM      Lainnya
# 310           0           0     119 m²         72 m²   Hak Sewa    2200 Watt
# 311           0           0     135 m²        152 m²        SHM    2200 Watt
#
#     Jumlah Lantai Kondisi Properti Kamar Tidur Pembantu Carport  \
# 0               2            Bagus                    1       1
# 1               1            Bagus                    1       2
# 2               1            Bagus                    1       4
# 3               2            Bagus                    1       5
# 4               1            Bagus                    1       2
# ..            ...              ...                  ...     ...
# 307             0                0                    0       0
# 308             0                0                    0       0
# 309             0                0                    0       0
# 310             0                0                    0       0
# 311             0                0                    0       0
#
#     Kamar Mandi Pembantu Garasi
# 0                      1      2
# 1                      2      1
# 2                      1      1
# 3                      1      1
# 4                      1      1
# ..                   ...    ...
# 307                    0      0
# 308                    0      0
# 309                    0      0
# 310                    0      0
# 311                    0      0
#
# [312 rows x 14 columns]
