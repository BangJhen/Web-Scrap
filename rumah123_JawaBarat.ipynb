# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time

headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}

# %%
main_webUrl = "https://www.rumah123.com/jual/jawa-barat/rumah/?page=1"

req_main = requests.get(main_webUrl, headers=headers)

# %%
main_html = BeautifulSoup(req_main.content, "html5lib")

# %%
max_page = main_html.find_all("li", attrs={"class": "ui-molecule-paginate__item"})
max_page = int(max_page[-1].text)
max_page
# Out:
# 2500

# %%
dataframe = {}
dataframe["Nama"] = []
dataframe["Harga"] = []

# %%
for i in range(1,200):
    webUrl = f"https://www.rumah123.com/jual/jawa-barat/rumah/?page={i}"
    req = requests.get(webUrl, headers=headers)
    
    html = BeautifulSoup(req.content, "html5lib")
    time.sleep(2)
    
    link_sections = html.find_all("div", attrs={"class" : "intersection-card-container"})

    for link_sec in link_sections:
        link = link_sec.find("h2").parent["href"]
        
        if "perumahan-baru" in link:
            continue
        try:
            sub_url = requests.get("https://www.rumah123.com" + link, headers=headers)
            sub_html = BeautifulSoup(sub_url.content, "html5lib")
            time.sleep(2)

            title = sub_html.find("h1", attrs={"class" :"text-gray-800 text mb-5"})
            dataframe["Nama"].append(title.text)
            
            specific_div = sub_html.find("div", attrs={"class" : "w-full md:w-[750px] self-stretch"})
            harga = specific_div.find("span")
            dataframe["Harga"].append(harga.text)

            property_div = sub_html.find("div",attrs={"id" : "property-information"})

            propertyes = [[prob.text,prob.nextSibling.text] for prob in property_div.find_all("p", attrs={"class":"w-32"})]
        except:
            continue
        
        print(link)
        for prop in propertyes:
            prop_key = prop[0]
            prop_value = prop[1]
            
            if not prop_key in dataframe.keys():
                dataframe[prop_key] = []
            
            if prop_key in dataframe.keys():
                dataframe[prop_key].append(prop_value)
            
        print("")
# Out:
# /properti/bekasi/hos16674010/
#
# /properti/depok/hos18917927/
#
# /properti/depok/hos18519133/
#
# /properti/bogor/hos18391957/
#
# /properti/bekasi/hos18919694/
#
# /properti/bekasi/hos18431335/
#
# /properti/bogor/hos18547436/
#
# /properti/bogor/hos18165982/
#
# /properti/bogor/hos18646978/
#
# /properti/depok/hos18563788/
#
# /properti/bogor/hos18162402/
#
# /properti/bekasi/hos18457382/
#
# /properti/bekasi/hos19134128/
#
# /properti/bogor/hos17510668/
#
# /properti/bekasi/hos18546733/
#
# /properti/depok/hos18125451/
#
# /properti/bekasi/hos18651787/
#
# /properti/bogor/hos18354228/
#
# /properti/depok/hos18716555/
#
# /properti/depok/hos18893260/
#
# /properti/depok/hos18112286/
#
# /properti/bogor/hos18204365/
#
# /properti/bogor/hos18647045/
#
# /properti/depok/hos19069667/
#
# /properti/depok/hos18744562/
#
# /properti/bogor/hos18165974/
#
# /properti/bogor/hos19069266/
#
# /properti/depok/hos18022126/
#
# /properti/depok/hos18061945/
#
# /properti/depok/hos18446706/
#
# /properti/bogor/hos18167012/
#
# /properti/bekasi/hos18191180/
#
# /properti/depok/hos14550995/
#
# /properti/bogor/hos18389844/
#
# /properti/bekasi/hos18446760/
#
# /properti/depok/hos18305081/
#
# /properti/depok/hos18093667/
#
# /properti/bogor/hos18920288/
#
# /properti/bekasi/hos18893780/
#
# /properti/depok/hos18055194/
#
# /properti/bogor/hos18204347/
#
# /properti/bogor/hos19199306/
#
# /properti/bekasi/hos18135201/
#
# /properti/bekasi/hos17285781/
#
# /properti/bekasi/hos18097943/
#
# /properti/depok/hos18744593/
#
# /properti/bekasi/hos17917639/
#
# /properti/bogor/hos19113513/
#
# /properti/depok/hos18508789/
#
# /properti/depok/hos15882717/
#
# /properti/bogor/hos18905852/
#
# /properti/bekasi/hos18191160/
#
# /properti/depok/hos15672654/
#
# /properti/depok/hos16875261/
#
# /properti/bogor/hos18139925/
#
# /properti/bogor/hos17077831/
#
# /properti/depok/hos15855159/
#
# /properti/bogor/hos18314507/
#
# /properti/bogor/hos18480471/
#
# /properti/bogor/hos18403644/
#
# /properti/depok/hos16048491/
#
# /properti/depok/hos18210174/
#
# /properti/bogor/hos18893248/
#
# /properti/depok/hos18165802/
#
# /properti/bogor/hos18917799/
#
# /properti/depok/hos18113677/
#
# /properti/depok/hos18240603/
#
# /properti/depok/hos13142962/
#
# /properti/bogor/hos18457293/
#
# /properti/bogor/hos18946814/
#
# /properti/bogor/hos19134079/
#
# /properti/bogor/hos18579446/
#
# /properti/bekasi/hos16772863/
#
# /properti/bekasi/hos18043123/
#
# /properti/bekasi/hos18390385/
#
# /properti/bekasi/hos18355722/
#
# /properti/depok/hos18550260/
#
# /properti/bogor/hos18431318/
#
# /properti/depok/hos18716556/
#
# /properti/bogor/hos17989057/
#
# /properti/depok/hos18218083/
#
# /properti/bekasi/hos18390396/
#
# /properti/bogor/hos18491380/
#
# /properti/bogor/hos18374707/
#
# /properti/bogor/hos16858462/
#
# /properti/depok/hos18574817/
#
# /properti/bogor/hos18204360/
#
# /properti/bekasi/hos18137948/
#
# /properti/depok/hos15956967/
#
# /properti/bogor/hos18403647/
#
# /properti/bekasi/hos17473221/
#
# /properti/bekasi/hos18103843/
#
# /properti/bekasi/hos19045664/
#
# /properti/depok/hos18744577/
#
# /properti/bogor/hos18108311/
#
# /properti/bogor/hos18919691/
#
# /properti/bekasi/hos18642193/
#
# /properti/depok/hos15964503/
#
# /properti/depok/hos18563369/
#
# /properti/bogor/hos18446703/
#
# /properti/bekasi/hos18183032/
#
# /properti/bogor/hos18564066/
#
# /properti/depok/hos14347806/
#
# /properti/bogor/hos18156471/
#
# /properti/bekasi/hos18224668/
#
# /properti/depok/hos17987986/
#
# /properti/bogor/hos18987968/
#
# /properti/bogor/hos18651816/
#
# /properti/bekasi/hos19134091/
#
# /properti/bekasi/hos18074397/
#
# /properti/bogor/hos18167022/
#
# /properti/bogor/hos18893255/
#
# /properti/bekasi/hos17285780/
#
# /properti/depok/hos18093649/
#
# /properti/bogor/hos18159122/
#
# /properti/bogor/hos17962171/
#
# /properti/bogor/hos18156488/
#
# /properti/bekasi/hos18490477/
#
# /properti/bogor/hos19113614/
#
# /properti/depok/hos18092573/
#
# /properti/bogor/hos18919725/
#
# /properti/bogor/hos18066057/
#
# /properti/bekasi/hos18305918/
#
# /properti/bogor/hos18687704/
#
# /properti/bekasi/hos18564483/
#
# /properti/bekasi/hos17071760/
#
# /properti/bogor/hos19256003/
#
# /properti/bekasi/hos19255852/
#
# /properti/depok/hos18576978/
#
# /properti/bekasi/hos18097932/
#
# /properti/bekasi/hos16052846/
#
# /properti/bekasi/hos18431255/
#
# /properti/bekasi/hos18687688/
#
# /properti/bogor/hos18314552/
#
# /properti/bogor/hos18564484/
#
# /properti/depok/hos17082067/
#
# /properti/bekasi/hos18072081/
#
# /properti/bogor/hos19199348/
#
# /properti/bekasi/hos18043005/
#
# /properti/bekasi/hos18480458/
#
# /properti/bogor/hos18947172/
#
# /properti/bogor/hos18158326/
#
# /properti/bogor/hos18208269/
#
# /properti/bekasi/hos18042924/
#
# /properti/bekasi/hos18162434/
#
# /properti/bogor/hos17962080/
#
# /properti/bogor/hos18159017/
#
# /properti/bogor/hos18579457/
#
# /properti/bogor/hos18389838/
#
# /properti/bekasi/hos18567348/
#
# /properti/depok/hos18328355/
#
# /properti/depok/hos17979243/
#
# /properti/depok/hos18112265/
#
# /properti/depok/hos18647037/
#
# /properti/bogor/hos18896934/
#
# /properti/depok/hos18920305/
#
# /properti/bogor/hos17079792/
#
# /properti/bogor/hos18139924/
#
# /properti/bekasi/hos16861838/
#
# /properti/bogor/hos18893257/
#
# /properti/depok/hos18374780/
#
# /properti/bekasi/hos18286961/
#
# /properti/bogor/hos18685175/
#
# /properti/bogor/hos19134133/
#
# /properti/bogor/hos18491359/
#
# /properti/depok/hos18304588/
#
# /properti/bekasi/hos18642192/
#
# /properti/bogor/hos18685248/
#
# /properti/bogor/hos18988010/
#
# /properti/bogor/hos19045847/
#
# /properti/bogor/hos18129143/
#
# /properti/bekasi/hos18203984/
#
# /properti/depok/hos18575895/
#
# /properti/depok/hos18563386/
#
# /properti/depok/hos18632929/
#
# /properti/bogor/hos18893199/
#
# /properti/bogor/hos18566534/
#
# /properti/bogor/hos18919701/
#
# /properti/bogor/hos18354199/
#
# /properti/bekasi/hos18905277/
#
# /properti/bekasi/hos18685084/
#
# /properti/bogor/hos18893225/
#
# /properti/depok/hos18848131/
#
# /properti/bandung/hos19172511/
#
# /properti/bogor/hos16812257/
#
# /properti/bogor/hos18389840/
#
# /properti/bogor/hos18354233/
#
# /properti/depok/hos18243093/
#
# /properti/depok/hos18457363/
#
# /properti/depok/hos17957508/
#
# /properti/bekasi/hos18135270/
#
# /properti/depok/hos18744539/
#
# /properti/depok/hos17081410/
#
# /properti/bogor/hos18546781/
#
# /properti/bogor/hos18354193/
#
# /properti/bogor/hos18399452/
#
# /properti/bekasi/hos18546745/
#
# /properti/depok/hos18630853/
#
# /properti/bogor/hos17063956/
#
# /properti/bogor/hos18917950/
#
# /properti/bogor/hos18354213/
#
# /properti/bogor/hos16376772/
#
# /properti/bekasi/hos19113280/
#
# /properti/bogor/hos16264648/
#
# /properti/bogor/hos18287776/
#
# /properti/bekasi/hos18072074/
#
# /properti/depok/hos16263532/
#
# /properti/bogor/hos18104828/
#
# /properti/bogor/hos18547401/
#
# /properti/bekasi/hos18899542/
#
# /properti/bekasi/hos18576624/
#
# /properti/depok/hos18092595/
#
# /properti/depok/hos14248521/
#
# /properti/bekasi/hos18563407/
#
# /properti/bekasi/hos18685105/
#
# /properti/bogor/hos18917923/
#
# /properti/bekasi/hos18062036/
#
# /properti/bekasi/hos18043078/
#
# /properti/bogor/hos16862856/
#
# /properti/bogor/hos18399411/
#
# /properti/depok/hos17604057/
#
# /properti/depok/hos18356868/
#
# /properti/bogor/hos18401260/
#
# /properti/bogor/hos18204358/
#
# /properti/bogor/hos18646961/
#
# /properti/bekasi/hos18568050/
#
# /properti/depok/hos18744530/
#
# /properti/bogor/hos18401191/
#
# /properti/depok/hos18896904/
#
# /properti/bogor/hos18546787/
#
# /properti/bekasi/hos18522623/
#
# /properti/bekasi/hos17268769/
#
# /properti/depok/hos18905849/
#
# /properti/depok/hos18016521/
#
# /properti/bogor/hos18491385/
#
# /properti/depok/hos16047716/
#
# /properti/depok/hos19045672/
#
# /properti/depok/hos16599605/
#
# /properti/bogor/hos18178956/
#
# /properti/depok/hos18210171/
#
# /properti/bogor/hos18564037/
#
# /properti/bekasi/hos18918573/
#
# /properti/bogor/hos18547389/
#
# /properti/bogor/hos18066056/
#
# /properti/depok/hos17991505/
#
# /properti/bogor/hos18575907/
#
# /properti/bogor/hos18687725/
#
# /properti/depok/hos18093673/
#
# /properti/bekasi/hos18905862/
#
# /properti/depok/hos19199345/
#
# /properti/bogor/hos18480461/
#
# /properti/bogor/hos18335283/
#
# /properti/depok/hos18093638/
#
# /properti/bekasi/hos18203982/
#
# /properti/bogor/hos17510716/
#
# /properti/bogor/hos18159259/
#
# /properti/bogor/hos18685179/
#
# /properti/bandung/hos19284725/
#
# /properti/bandung/hos19213078/
#
# /properti/bandung/hos17336883/
#
# /properti/bekasi/hos19262491/
#
# /properti/depok/hos18881709/
#
# /properti/bekasi/hos19149432/
#
# /properti/bekasi/hos19199647/
#
# /properti/bandung/hos18750142/
#
# /properti/bandung/hos19172428/
#
# /properti/bogor/hos15345665/
#
# /properti/bogor/hos16750106/
#
# /properti/bekasi/hos19202749/
#
# /properti/bandung/hos18987921/
#
# /properti/depok/hos19187524/
#
# /properti/depok/hos19098638/
#
# /properti/bogor/hos19199933/
#
# /properti/depok/hos18981800/
#
# /properti/bandung/hos18481046/
#
# /properti/bekasi/hos18793750/
#
# /properti/bandung/hos19359826/
#
# /properti/bandung/hos18808219/
#
# /properti/bogor/hos14957879/
#
# /properti/bandung/hos19006422/
#
# /properti/bandung/hos19361487/
#
# /properti/bandung/hos7796621/
#
# /properti/bekasi/hos19048750/
#
# /properti/bogor/hos17873128/
#
# /properti/bandung/hos18130074/
#
# /properti/bekasi/hos19313152/
#
# /properti/bekasi/hos16106327/
#
# /properti/bogor/hos19312561/
#
# /properti/bekasi/hos18573074/
#
# /properti/bekasi/hos18043603/
#
# /properti/bogor/hos18388055/
#
# /properti/bogor/hos19255854/
#
# /properti/bekasi/hos18917394/
#
# /properti/bekasi/hos18188711/
#
# /properti/bogor/hos19069283/
#
# /properti/bogor/hos18407791/
#
# /properti/depok/hos17081996/
#
# /properti/bogor/hos18564490/
#
# /properti/bekasi/hos18135251/
#
# /properti/depok/hos16817996/
#
# /properti/bogor/hos18686435/
#
# /properti/bogor/hos18896895/
#
# /properti/bogor/hos18947834/
#
# /properti/bogor/hos18159022/
#
# /properti/bekasi/hos18429444/
#
# /properti/depok/hos18630877/
#
# /properti/bekasi/hos18642003/
#
# /properti/bogor/hos18158273/
#
# /properti/bogor/hos18315171/
#
# /properti/bogor/hos18166996/
#
# /properti/bogor/hos18412069/
#
# /properti/depok/hos16863962/
#
# /properti/bekasi/hos18183059/
#
# /properti/depok/hos18533246/
#
# /properti/depok/hos17875190/
#
# /properti/depok/hos18589228/
#
# /properti/depok/hos18115813/
#
# /properti/depok/hos18917925/
#
# /properti/bogor/hos18893207/
#
# /properti/bogor/hos18307435/
#
# /properti/bekasi/hos18097935/
#
# /properti/bekasi/hos18300026/
#
# /properti/depok/hos18744592/
#
# /properti/bekasi/hos18071965/
#
# /properti/bogor/hos18158331/
#
# /properti/depok/hos18893878/
#
# /properti/bandung/hos13393860/
#
# /properti/bekasi/hos18996214/
#
# /properti/bekasi/hos14780915/
#
# /properti/bogor/hos12897907/
#
# /properti/depok/hos18284070/
#
# /properti/bandung/hos14753709/
#
# /properti/bandung/hos14780422/
#
# /properti/bekasi/hos18318536/
#
# /properti/depok/hos18347268/
#
# /properti/bandung/hos13356903/
#
# /properti/bogor/hos12870374/
#
# /properti/bekasi/hos13427245/
#
# /properti/depok/hos13441353/
#
# /properti/bekasi/hos13236106/
#
# /properti/bekasi/hos13433581/
#
# /properti/bandung/hos18284104/
#
# /properti/cirebon/hos18284103/
#
# /properti/bandung/hos18284106/
#
# /properti/cirebon/hos18284097/
#
# /properti/bandung/hos18284091/
#
# /properti/bandung/hos18702916/
#
# /properti/bogor/hos18951000/
#
# /properti/bekasi/hos18702902/
#
# /properti/bekasi/hos18702921/
#
# /properti/bandung/hos18284101/
#
# /properti/depok/hos18702919/
#
# /properti/bandung/hos18702915/
#
# /properti/depok/hos18724413/
#
# /properti/bogor/hos18651813/
#
# /properti/bogor/hos18419569/
#
# /properti/bekasi/hos18071950/
#
# /properti/bekasi/hos19254911/
#
# /properti/depok/hos18269710/
#
# /properti/bekasi/hos16157185/
#
# /properti/depok/hos18533230/
#
# /properti/bogor/hos18579414/
#
# /properti/bekasi/hos18330886/
#
# /properti/depok/hos16068211/
#
# /properti/bekasi/hos18493259/
#
# /properti/depok/hos17483509/
#
# /properti/bogor/hos18547477/
#
# /properti/depok/hos16787511/
#
# /properti/depok/hos18533239/
#
# /properti/depok/hos18450943/
#
# /properti/bogor/hos17079768/
#
# /properti/bogor/hos18564498/
#
# /properti/depok/hos17656202/
#
# /properti/bogor/hos18566535/
#
# /properti/depok/hos17483489/
#
# /properti/bekasi/hos18579429/
#
# /properti/bekasi/hos18043502/
#
# /properti/depok/hos17980358/
#
# /properti/bogor/hos18563372/
#
# /properti/depok/hos18744558/
#
# /properti/depok/hos18047783/
#
# /properti/depok/hos18917391/
#
# /properti/depok/hos14301389/
#
# /properti/depok/hos11252095/
#
# /properti/depok/hos17079770/
#
# /properti/bekasi/hos18071973/
#
# /properti/depok/hos18450892/
#
# /properti/bekasi/hos18895058/
#
# /properti/depok/hos16833812/
#
# /properti/bekasi/hos18300022/
#
# /properti/depok/hos17082784/
#
# /properti/bogor/hos18431360/
#
# /properti/bekasi/hos18047793/
#
# /properti/depok/hos9921065/
#
# /properti/depok/hos18055086/
#
# /properti/bekasi/hos18546751/
#
# /properti/depok/hos16659128/
#
# /properti/bekasi/hos18568052/
#
# /properti/bekasi/hos17919009/
#
# /properti/bogor/hos18915917/
#
# /properti/depok/hos18918576/
#
# /properti/depok/hos18987943/
#
# /properti/bogor/hos18403624/
#
# /properti/bogor/hos18159267/
#
# /properti/bogor/hos18642321/
#
# /properti/bogor/hos18947845/
#
# /properti/bogor/hos18156487/
#
# /properti/depok/hos18920272/
#
# /properti/bogor/hos18987988/
#
# /properti/bogor/hos17222173/
#
# /properti/bekasi/hos16270589/
#
# /properti/bogor/hos18648797/
#
# /properti/bogor/hos18949046/
#
# /properti/depok/hos18072072/
#
# /properti/bogor/hos18647040/
#
# /properti/depok/hos18519141/
#
# /properti/depok/hos17297662/
#
# /properti/bogor/hos18547431/
#
# /properti/bogor/hos18061907/
#
# /properti/bogor/hos18647054/
#
# /properti/depok/hos15922030/
#
# /properti/bekasi/hos17769959/
#
# /properti/depok/hos18493263/
#
# /properti/bekasi/hos17919015/
#
# /properti/depok/hos18647004/
#
# /properti/depok/hos18240691/
#
# /properti/depok/hos18579171/
#
# /properti/bogor/hos18987991/
#
# /properti/bekasi/hos17268770/
#
# /properti/depok/hos16646852/
#
# /properti/bogor/hos18158303/
#
# /properti/bogor/hos15995178/
#
# /properti/bogor/hos18315125/
#
# /properti/bekasi/hos18305870/
#
# /properti/bogor/hos15831766/
#
# /properti/bogor/hos18917388/
#
# /properti/depok/hos18055088/
#
# /properti/depok/hos18920491/
#
# /properti/bogor/hos18946809/
#
# /properti/depok/hos18546778/
#
# /properti/bogor/hos18890530/
#
# /properti/depok/hos18647047/
#
# /properti/bogor/hos18407766/
#
# /properti/depok/hos16753444/
#
# /properti/bekasi/hos17491751/
#
# /properti/bogor/hos17035855/
#
# /properti/depok/hos18651773/
#
# /properti/bogor/hos18446687/
#
# /properti/bekasi/hos18304518/
#
# /properti/depok/hos18127940/
#
# /properti/depok/hos16043971/
#
# /properti/bekasi/hos18304497/
#
# /properti/bekasi/hos18072058/
#
# /properti/bekasi/hos18578355/
#
# /properti/bekasi/hos18072058/
#
# /properti/bekasi/hos18578355/
#
# /properti/bekasi/hos18459823/
#
# /properti/bogor/hos17287250/
#
# /properti/bekasi/hos18546744/
#
# /properti/depok/hos18914775/
#
# /properti/depok/hos18307409/
#
# /properti/bekasi/hos18304468/
#
# /properti/depok/hos18575874/
#
# /properti/bogor/hos18538707/
#
# /properti/depok/hos16833816/
#
# /properti/bogor/hos18640497/
#
# /properti/bogor/hos18946811/
#
# /properti/bekasi/hos17473217/
#
# /properti/depok/hos17082066/
#
# /properti/bekasi/hos18920293/
#
# /properti/bekasi/hos18446723/
#
# /properti/bogor/hos18646962/
#
# /properti/bogor/hos17989016/
#
# /properti/depok/hos18344666/
#
# /properti/bekasi/hos18042996/
#
# /properti/bekasi/hos18062030/
#
# /properti/bekasi/hos18538589/
#
# /properti/bekasi/hos17318169/
#
# /properti/depok/hos18022128/
#
# /properti/bandung/hos17118441/
#
# /properti/bandung/hos19084946/
#
# /properti/bogor/hos18410769/
#
# /properti/bekasi/hos18224632/
#
# /properti/bogor/hos18917800/
#
# /properti/bogor/hos17770846/
#
# /properti/bekasi/hos17219497/
#
# /properti/depok/hos18240690/
#
# /properti/bogor/hos18407797/
#
# /properti/depok/hos16787508/
#
# /properti/bekasi/hos18917803/
#
# /properti/bogor/hos18058684/
#
# /properti/depok/hos16548692/
#
# /properti/depok/hos16264640/
#
# /properti/bekasi/hos19199312/
#
# /properti/depok/hos16363446/
#
# /properti/depok/hos18125475/
#
# /properti/depok/hos18987976/
#
# /properti/bekasi/hos17050846/
#
# /properti/depok/hos18947192/
#
# /properti/depok/hos18519263/
#
# /properti/bekasi/hos18596846/
#
# /properti/depok/hos18919670/
#
# /properti/bogor/hos18920270/
#
# /properti/bogor/hos18546780/
#
# /properti/bandung/hos19032198/
#
# /properti/bandung/hos19032195/
#
# /properti/bekasi/hos18306453/
#
# /properti/depok/hos17980363/
#
# /properti/depok/hos16629238/
#
# /properti/depok/hos18905863/
#
# /properti/depok/hos18589227/
#
# /properti/bekasi/hos18240618/
#
# /properti/bandung/hos19251312/
#
# /properti/bandung/hos19251274/
#
# /properti/bandung/hos19251162/
#
# /properti/depok/hos18991476/
#
# /properti/bekasi/hos18243455/
#
# /properti/depok/hos18934951/
#
# /properti/bandung/hos19244683/
#
# /properti/bogor/hos18594316/
#
# /properti/bekasi/hos10778082/
#
# /properti/bogor/hos18225375/
#
# /properti/bogor/hos18225352/
#
# /properti/depok/hos18158224/
#
# /properti/bogor/hos18241540/
#
# /properti/bekasi/hos18356591/
#
# /properti/bekasi/hos18474829/
#
# /properti/bekasi/hos18217046/
#
# /properti/depok/hos18284624/
#
# /properti/bekasi/hos18794668/
#
# /properti/bogor/hos18284644/
#
# /properti/depok/hos18292732/
#
# /properti/depok/hos18135754/
#
# /properti/bekasi/hos18301277/
#
# /properti/bogor/hos18284648/
#
# /properti/bekasi/hos18284623/
#
# /properti/bogor/hos19197204/
#
# /properti/bekasi/hos18686153/
#
# /properti/depok/hos18921675/
#
# /properti/bogor/hos18186385/
#
# /properti/bekasi/hos18695075/
#
# /properti/bogor/hos18225374/
#
# /properti/bogor/hos18225383/
#
# /properti/bekasi/hos18292739/
#
# /properti/bogor/hos18284646/
#
# /properti/bekasi/hos18217044/
#
# /properti/depok/hos18225410/
#
# /properti/bogor/hos18284638/
#
# /properti/cimahi/hos19195847/
#
# /properti/depok/hos18284647/
#
# /properti/depok/hos18284634/
#
# /properti/bogor/hos18284626/
#
# /properti/bekasi/hos18225351/
#
# /properti/depok/hos18204250/
#
# /properti/bandung/hos19193418/
#
# /properti/depok/hos18284640/
#
# /properti/depok/hos18356774/
#
# /properti/bogor/hos18158225/
#
# /properti/bogor/hos18301274/
#
# /properti/bogor/hos18268166/
#
# /properti/bogor/hos18284627/
#
# /properti/depok/hos18204264/
#
# /properti/bandung/hos19193258/
#
# /properti/depok/hos18167271/
#
# /properti/bogor/hos18204253/
#
# /properti/bogor/hos18241553/
#
# /properti/bandung/hos14295590/
#
# /properti/bandung/hos19192061/
#
# /properti/bandung/hos19191916/
#
# /properti/bekasi/hos19191882/
#
# /properti/bandung/hos19191657/
#
# /properti/bogor/hos19190947/
#
# /properti/bogor/hos19190934/
#
# /properti/bogor/hos18741079/
#
# /properti/bandung/hos18307070/
#
# /properti/bogor/hos18697002/
#
# /properti/bogor/hos18551438/
#
# /properti/depok/hos18149518/
#
# /properti/depok/hos18149444/
#
# /properti/depok/hos18286469/
#
# /properti/bandung/hos16523570/
#
# /properti/bekasi/hos19281462/
#
# /properti/bandung/hos19209258/
#
# /properti/bandung/hos19082671/
#
# /properti/depok/hos18853694/
#
# /properti/depok/hos18853693/
#
# /properti/depok/hos18853691/
#
# /properti/bogor/hos18853689/
#
# /properti/bogor/hos18888799/
#
# /properti/bogor/hos18853688/
#
# /properti/bandung-barat/hos18581272/
#
# /properti/bogor/hos18888798/
#
# /properti/bekasi/hos18888797/
#
# /properti/bekasi/hos18855753/
#
# /properti/bandung/hos19357239/
#
# /properti/bekasi/hos18836582/
#
# /properti/depok/hos18836571/
#
# /properti/depok/hos18836570/
#
# /properti/depok/hos18836568/
#
# /properti/bekasi/hos18855748/
#
# /properti/bekasi/hos18836548/
#
# /properti/bekasi/hos18836546/
#
# /properti/depok/hos19355822/
#
# /properti/bekasi/hos19337993/
#
# /properti/depok/hos17294546/
#
# /properti/bandung/hos19127070/
#
# /properti/bandung/hos19335683/
#
# /properti/bekasi/hos16059378/
#
# /properti/bekasi/hos19227283/
#
# /properti/bekasi/hos19293748/
#
# /properti/bandung/hos17080207/
#
# /properti/bandung/hos17136583/
#
# /properti/bandung/hos19238563/
#
# /properti/bandung/hos19299441/
#
# /properti/bogor/hos19299325/
#
# /properti/bogor/hos19299284/
#
# /properti/bandung/hos19298904/
#
# /properti/bandung/hos18129910/
#
# /properti/depok/hos16384614/
#
# /properti/depok/hos16923272/
#
# /properti/bekasi/hos17480199/
#
# /properti/bandung/hos19246740/
#
# /properti/bandung/hos19246706/

# %%
rumah123_df = pd.DataFrame.from_dict(dataframe, orient='index').T
rumah123_df = rumah123_df.fillna(0)
rumah123_df.to_json("Provinsi_JawaBarat.json", orient="records")

# %%
rumah123_df
# Out:
#                                                   Nama           Harga  \
# 0    Rumah 2 Lantai SHM 15 Menit Ke Grand Galaxy Pa...     Rp 980 Juta
# 1    Rumah SHM LT 219 Bisa Nego 15 Mnt ke Stasiun D...   Rp 3,1 Miliar
# 2    Rumah Luas 2 Lt Strategis Bisa Nego 15 Mnt ke ...  Rp 3,04 Miliar
# 3    Rumah Gratis Renov dekat Pintu Tol Sentul Siap...     Rp 730 Juta
# 4    Rumah 5 Kamar Tidur SHM 10 Menit ke Siloam Hos...  Rp 1,05 Miliar
# ..                                                 ...             ...
# 618  Modern House Fully Furnished Hadap Utara di Ci...   Rp 8,9 Miliar
# 619   Rumah Minimalis 2 Lantai Bangunan Baru di Cinere   Rp 1,6 Miliar
# 620  Rumah Nyaman Homy 2 Lantai Di Caman,jatibening...   Rp 1,3 Miliar
# 621  Rumah Mewah Siap Huni Di Lokasi Favorit Cijagr...   Rp 2,2 Miliar
# 622   Dijhal Rumah Siap Huni Di Margahayu Raya Bandung   Rp 1,2 Miliar
#
#     Kamar Tidur Kamar Mandi Luas Tanah Luas Bangunan Sertifikat Daya Listrik  \
# 0             3           2      80 m²        160 m²        SHM    3500 Watt
# 1             3           4     219 m²        300 m²        SHM    2200 Watt
# 2             6           4     170 m²        265 m²        SHM    3500 Watt
# 3             3           2      78 m²         98 m²        SHM    1300 Watt
# 4             5           3     108 m²        108 m²        SHM    2200 Watt
# ..          ...         ...        ...           ...        ...          ...
# 618           3           3     500 m²        350 m²        SHM    3300 Watt
# 619           3           2     102 m²        200 m²        SHM    5500 Watt
# 620           0           0      84 m²        140 m²        SHM    2200 Watt
# 621           0           0     119 m²        220 m²        SHM      Lainnya
# 622           0           0      86 m²        160 m²        SHM      Lainnya
#
#     Jumlah Lantai Kondisi Properti Kamar Tidur Pembantu Carport Garasi  \
# 0               2            Bagus                    1       1      1
# 1               1            Bagus                    1       1      1
# 2               2            Bagus                    1       1      1
# 3               2            Bagus                    1       1      1
# 4               2            Bagus                    1       1      1
# ..            ...              ...                  ...     ...    ...
# 618             0                0                    0       0      0
# 619             0                0                    0       0      0
# 620             0                0                    0       0      0
# 621             0                0                    0       0      0
# 622             0                0                    0       0      0
#
#     Kamar Mandi Pembantu
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 618                    0
# 619                    0
# 620                    0
# 621                    0
# 622                    0
#
# [623 rows x 14 columns]
