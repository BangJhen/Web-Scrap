# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time

headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}

# %%
main_webUrl = "https://www.rumah123.com/jual/daerah-istimewa-yogyakarta/rumah/?page=1"

req_main = requests.get(main_webUrl, headers=headers)

# %%
main_html = BeautifulSoup(req_main.content, "html5lib")

# %%
max_page = main_html.find_all("li", attrs={"class": "ui-molecule-paginate__item"})
max_page = int(max_page[-1].text)
max_page
# Out:
# 1240

# %%
dataframe = {}
dataframe["Nama"] = []
dataframe["Harga"] = []

# %%
for i in range(1, 200):
    webUrl = f"https://www.rumah123.com/jual/daerah-istimewa-yogyakarta/rumah/?page={i}"
    req = requests.get(webUrl, headers=headers)
    
    html = BeautifulSoup(req.content, "html5lib")
    time.sleep(2)
    
    link_sections = html.find_all("div", attrs={"class" : "intersection-card-container"})

    for link_sec in link_sections:
        link = link_sec.find("h2").parent["href"]
        
        if "perumahan-baru" in link:
            continue
        try:
            sub_url = requests.get("https://www.rumah123.com" + link, headers=headers)
            sub_html = BeautifulSoup(sub_url.content, "html5lib")
            time.sleep(2)

            title = sub_html.find("h1", attrs={"class" :"text-gray-800 text mb-5"})
            dataframe["Nama"].append(title.text)
            
            specific_div = sub_html.find("div", attrs={"class" : "w-full md:w-[750px] self-stretch"})
            harga = specific_div.find("span")
            dataframe["Harga"].append(harga.text)

            property_div = sub_html.find("div",attrs={"id" : "property-information"})

            propertyes = [[prob.text,prob.nextSibling.text] for prob in property_div.find_all("p", attrs={"class":"w-32"})]
        except:
            continue
        
        print(link)
        for prop in propertyes:
            prop_key = prop[0]
            prop_value = prop[1]
            
            if not prop_key in dataframe.keys():
                dataframe[prop_key] = []
            
            if prop_key in dataframe.keys():
                dataframe[prop_key].append(prop_value)
            
        print("")
# Out:
# /properti/sleman/hos19285267/
#
# /properti/sleman/hos19066436/
#
# /properti/bantul/hos19231395/
#
# /properti/sleman/hos18664313/
#
# /properti/sleman/hos19232666/
#
# /properti/sleman/hos19232657/
#
# /properti/yogyakarta/hos19232636/
#
# /properti/yogyakarta/hos12589812/
#
# /properti/yogyakarta/hos19232576/
#
# /properti/sleman/hos19232437/
#
# /properti/sleman/hos19232401/
#
# /properti/bantul/hos19232395/
#
# /properti/yogyakarta/hos19232373/
#
# /properti/yogyakarta/hos19232244/
#
# /properti/bantul/hos19232210/
#
# /properti/sleman/hos19232173/
#
# /properti/sleman/hos19231983/
#
# /properti/yogyakarta/hos19231947/
#
# /properti/sleman/hos19085328/
#
# /properti/sleman/hos19230191/
#
# /properti/yogyakarta/hos19231831/
#
# /properti/sleman/hos13923535/
#
# /properti/sleman/hos18786014/
#
# /properti/sleman/hos19221203/
#
# /properti/yogyakarta/hos15590962/
#
# /properti/bantul/hos19230915/
#
# /properti/yogyakarta/hos18695067/
#
# /properti/sleman/hos19231348/
#
# /properti/sleman/hos18695106/
#
# /properti/sleman/hos19231311/
#
# /properti/sleman/hos19086204/
#
# /properti/sleman/hos19231201/
#
# /properti/sleman/hos18879276/
#
# /properti/sleman/hos16076367/
#
# /properti/bantul/hos19231102/
#
# /properti/bantul/hos19231088/
#
# /properti/sleman/hos19231047/
#
# /properti/kulon-progo/hos19005933/
#
# /properti/bantul/hos13620402/
#
# /properti/sleman/hos19230640/
#
# /properti/sleman/hos19230509/
#
# /properti/sleman/hos19112884/
#
# /properti/sleman/hos19230472/
#
# /properti/sleman/hos19230424/
#
# /properti/sleman/hos19230418/
#
# /properti/yogyakarta/hos19230184/
#
# /properti/sleman/hos19028802/
#
# /properti/yogyakarta/hos18909943/
#
# /properti/yogyakarta/hos19004285/
#
# /properti/sleman/hos18071525/
#
# /properti/sleman/hos19229751/
#
# /properti/sleman/hos19178815/
#
# /properti/sleman/hos19178752/
#
# /properti/sleman/hos19178648/
#
# /properti/sleman/hos19178644/
#
# /properti/sleman/hos19178284/
#
# /properti/sleman/hos19178271/
#
# /properti/sleman/hos19178210/
#
# /properti/sleman/hos19178209/
#
# /properti/sleman/hos18514961/
#
# /properti/sleman/hos16652908/
#
# /properti/sleman/hos18061851/
#
# /properti/bantul/hos19177815/
#
# /properti/sleman/hos17694825/
#
# /properti/yogyakarta/hos18358109/
#
# /properti/yogyakarta/hos18505619/
#
# /properti/sleman/hos18985167/
#
# /properti/sleman/hos18086919/
#
# /properti/sleman/hos17651589/
#
# /properti/sleman/hos18756764/
#
# /properti/yogyakarta/hos18054797/
#
# /properti/sleman/hos18117640/
#
# /properti/sleman/hos17884427/
#
# /properti/sleman/hos19168743/
#
# /properti/sleman/hos19161291/
#
# /properti/sleman/hos14799834/
#
# /properti/sleman/hos19177711/
#
# /properti/sleman/hos19177601/
#
# /properti/sleman/hos19153315/
#
# /properti/yogyakarta/hos19175925/
#
# /properti/sleman/hos19177296/
#
# /properti/yogyakarta/hos19177263/
#
# /properti/sleman/hos19177249/
#
# /properti/sleman/hos19177169/
#
# /properti/sleman/hos19177174/
#
# /properti/bantul/hos19177108/
#
# /properti/sleman/hos19177001/
#
# /properti/sleman/hos19176970/
#
# /properti/yogyakarta/hos19176943/
#
# /properti/bantul/hos19176698/
#
# /properti/yogyakarta/hos19176351/
#
# /properti/sleman/hos14237368/
#
# /properti/sleman/hos19176293/
#
# /properti/bantul/hos19176244/
#
# /properti/sleman/hos18963974/
#
# /properti/bantul/hos19175603/
#
# /properti/sleman/hos19175530/
#
# /properti/sleman/hos18987698/
#
# /properti/sleman/hos19150588/
#
# /properti/sleman/hos18901728/
#
# /properti/sleman/hos18200267/
#
# /properti/yogyakarta/hos19175435/
#
# /properti/yogyakarta/hos19175412/
#
# /properti/sleman/hos19176035/
#
# /properti/sleman/hos19176016/
#
# /properti/sleman/hos19176013/
#
# /properti/yogyakarta/hos19175997/
#
# /properti/sleman/hos19175951/
#
# /properti/sleman/hos19175921/
#
# /properti/sleman/hos19175897/
#
# /properti/sleman/hos19098889/
#
# /properti/yogyakarta/hos19175399/
#
# /properti/sleman/hos19175315/
#
# /properti/kulon-progo/hos19161405/
#
# /properti/sleman/hos19175277/
#
# /properti/sleman/hos19158634/
#
# /properti/sleman/hos19158634/
#
# /properti/bantul/hos18626907/
#
# /properti/sleman/hos18910025/
#
# /properti/sleman/hos19158110/
#
# /properti/sleman/hos19154013/
#
# /properti/sleman/hos19158731/
#
# /properti/sleman/hos19008090/
#
# /properti/sleman/hos17538027/
#
# /properti/bantul/hos19170643/
#
# /properti/sleman/hos19139467/
#
# /properti/sleman/hos19139268/
#
# /properti/sleman/hos19138949/
#
# /properti/sleman/hos19138923/
#
# /properti/sleman/hos19138881/
#
# /properti/sleman/hos19091505/
#
# /properti/sleman/hos18881960/
#
# /properti/sleman/hos18961968/
#
# /properti/sleman/hos17944232/
#
# /properti/yogyakarta/hos15959266/
#
# /properti/sleman/hos19126900/
#
# /properti/sleman/hos18848114/
#
# /properti/sleman/hos18994198/
#
# /properti/gunung-kidul/hos19138494/
#
# /properti/yogyakarta/hos19137956/
#
# /properti/sleman/hos19137951/
#
# /properti/bantul/hos19137840/
#
# /properti/yogyakarta/hos18765983/
#
# /properti/yogyakarta/hos19137745/
#
# /properti/sleman/hos19137734/
#
# /properti/sleman/hos19137733/
#
# /properti/yogyakarta/hos19095046/
#
# /properti/sleman/hos19083099/
#
# /properti/sleman/hos19137568/
#
# /properti/bantul/hos18712361/
#
# /properti/yogyakarta/hos19136843/
#
# /properti/sleman/hos19124482/
#
# /properti/sleman/hos18712285/
#
# /properti/bantul/hos18712298/
#
# /properti/yogyakarta/hos19036236/
#
# /properti/sleman/hos19135358/
#
# /properti/sleman/hos18784927/
#
# /properti/yogyakarta/hos19135308/
#
# /properti/sleman/hos19135268/
#
# /properti/bantul/hos19089137/
#
# /properti/sleman/hos18607097/
#
# /properti/sleman/hos18691999/
#
# /properti/yogyakarta/hos19089049/
#
# /properti/bantul/hos19088994/
#
# /properti/sleman/hos19088058/
#
# /properti/sleman/hos19088032/
#
# /properti/sleman/hos19087991/
#
# /properti/sleman/hos19087976/
#
# /properti/sleman/hos19087974/
#
# /properti/sleman/hos19087951/
#
# /properti/bantul/hos19087930/
#
# /properti/sleman/hos19087908/
#
# /properti/sleman/hos19087886/
#
# /properti/sleman/hos19087885/
#
# /properti/sleman/hos19087828/
#
# /properti/sleman/hos19087764/
#
# /properti/sleman/hos19087719/
#
# /properti/sleman/hos19087698/
#
# /properti/bantul/hos19087702/
#
# /properti/yogyakarta/hos19087701/
#
# /properti/sleman/hos19087675/
#
# /properti/sleman/hos19087661/
#
# /properti/bantul/hos19087662/
#
# /properti/sleman/hos19087563/
#
# /properti/sleman/hos19087493/
#
# /properti/sleman/hos19087481/
#
# /properti/sleman/hos19087031/
#
# /properti/yogyakarta/hos19087029/
#
# /properti/sleman/hos19087014/
#
# /properti/bantul/hos19086960/
#
# /properti/sleman/hos19086943/
#
# /properti/bantul/hos19086895/
#
# /properti/sleman/hos19086849/
#
# /properti/sleman/hos19086849/
#
# /properti/sleman/hos19086814/
#
# /properti/sleman/hos19032102/
#
# /properti/sleman/hos19086740/
#
# /properti/bantul/hos19086603/
#
# /properti/yogyakarta/hos18382518/
#
# /properti/sleman/hos19086455/
#
# /properti/yogyakarta/hos19063469/
#
# /properti/sleman/hos19086367/
#
# /properti/sleman/hos19086349/
#
# /properti/sleman/hos19086283/
#
# /properti/sleman/hos19086261/
#
# /properti/sleman/hos19086221/
#
# /properti/bantul/hos19086100/
#
# /properti/sleman/hos19086094/
#
# /properti/bantul/hos19086077/
#
# /properti/sleman/hos19086068/
#
# /properti/sleman/hos19085999/
#
# /properti/sleman/hos19085965/
#
# /properti/sleman/hos18612950/
#
# /properti/sleman/hos19085440/
#
# /properti/sleman/hos19085170/
#
# /properti/sleman/hos19065002/
#
# /properti/bantul/hos19084983/
#
# /properti/sleman/hos19084999/
#
# /properti/bantul/hos18864042/
#
# /properti/bantul/hos19084981/
#
# /properti/bantul/hos19084916/
#
# /properti/kulon-progo/hos19075990/
#
# /properti/bantul/hos19076055/
#
# /properti/sleman/hos16573605/
#
# /properti/bantul/hos19083088/
#
# /properti/bantul/hos19084871/
#
# /properti/bantul/hos19084871/
#
# /properti/bantul/hos19084802/
#
# /properti/sleman/hos19084795/
#
# /properti/sleman/hos19084772/
#
# /properti/sleman/hos19084704/
#
# /properti/bantul/hos19084720/
#
# /properti/bantul/hos18211101/
#
# /properti/sleman/hos19084653/
#
# /properti/sleman/hos19084641/
#
# /properti/bantul/hos19084617/
#
# /properti/bantul/hos19084595/
#
# /properti/sleman/hos19084575/
#
# /properti/sleman/hos19084553/
#
# /properti/bantul/hos19084539/
#
# /properti/yogyakarta/hos18896737/
#
# /properti/bantul/hos19084486/
#
# /properti/bantul/hos19084443/
#
# /properti/bantul/hos19084421/
#
# /properti/yogyakarta/hos19070875/
#
# /properti/sleman/hos19084359/
#
# /properti/bantul/hos19084320/
#
# /properti/sleman/hos19084241/
#
# /properti/bantul/hos17622058/
#
# /properti/sleman/hos18892292/
#
# /properti/bantul/hos19084201/
#
# /properti/sleman/hos18910054/
#
# /properti/yogyakarta/hos18892586/
#
# /properti/yogyakarta/hos18890186/
#
# /properti/sleman/hos16705816/
#
# /properti/sleman/hos19083729/
#
# /properti/sleman/hos18861490/
#
# /properti/sleman/hos18711931/
#
# /properti/yogyakarta/hos19083722/
#
# /properti/yogyakarta/hos17255448/
#
# /properti/yogyakarta/hos17621808/
#
# /properti/bantul/hos19083138/
#
# /properti/bantul/hos19083127/
#
# /properti/sleman/hos19083085/
#
# /properti/sleman/hos17621520/
#
# /properti/sleman/hos17621864/
#
# /properti/sleman/hos17621520/
#
# /properti/sleman/hos17621864/
#
# /properti/sleman/hos19082977/
#
# /properti/sleman/hos19082975/
#
# /properti/sleman/hos19082966/
#
# /properti/sleman/hos19082959/
#
# /properti/yogyakarta/hos19082945/
#
# /properti/bantul/hos19082944/
#
# /properti/sleman/hos19082938/
#
# /properti/sleman/hos19082924/
#
# /properti/sleman/hos19082925/
#
# /properti/sleman/hos19082889/
#
# /properti/sleman/hos19082828/
#
# /properti/sleman/hos19037235/
#
# /properti/sleman/hos19037228/
#
# /properti/yogyakarta/hos19037199/
#
# /properti/sleman/hos19037136/
#
# /properti/sleman/hos19037146/
#
# /properti/sleman/hos18749210/
#
# /properti/yogyakarta/hos19036809/
#
# /properti/yogyakarta/hos19036809/
#
# /properti/yogyakarta/hos19036602/
#
# /properti/sleman/hos19036566/
#
# /properti/sleman/hos19036554/
#
# /properti/sleman/hos19036521/
#
# /properti/bantul/hos19036520/
#
# /properti/bantul/hos19036514/
#
# /properti/bantul/hos19036500/
#
# /properti/sleman/hos19036427/
#
# /properti/kulon-progo/hos19036475/
#
# /properti/sleman/hos19036448/
#
# /properti/kulon-progo/hos19036407/
#
# /properti/yogyakarta/hos19036399/
#
# /properti/yogyakarta/hos19036353/
#
# /properti/sleman/hos19036343/
#
# /properti/yogyakarta/hos17809570/
#
# /properti/yogyakarta/hos19036318/
#
# /properti/sleman/hos19036269/
#
# /properti/sleman/hos18950929/
#
# /properti/kulon-progo/hos19036073/
#
# /properti/kulon-progo/hos19036030/
#
# /properti/yogyakarta/hos18971791/
#
# /properti/sleman/hos19035832/
#
# /properti/sleman/hos19035772/
#
# /properti/bantul/hos19035761/
#
# /properti/sleman/hos19035751/
#
# /properti/yogyakarta/hos19035685/
#
# /properti/sleman/hos19035662/
#
# /properti/sleman/hos19035607/
#
# /properti/yogyakarta/hos19035598/
#
# /properti/kulon-progo/hos19035577/
#
# /properti/sleman/hos19035572/
#
# /properti/sleman/hos19035570/
#
# /properti/bantul/hos19035545/
#
# /properti/sleman/hos19035519/
#
# /properti/sleman/hos19035514/
#
# /properti/sleman/hos19035486/
#
# /properti/sleman/hos19026179/
#
# /properti/sleman/hos19035323/
#
# /properti/sleman/hos19035292/
#
# /properti/sleman/hos19008962/
#
# /properti/sleman/hos19035070/
#
# /properti/sleman/hos19035069/
#
# /properti/sleman/hos19035068/
#
# /properti/sleman/hos14446208/
#
# /properti/sleman/hos18910797/
#
# /properti/bantul/hos19034757/
#
# /properti/sleman/hos19034655/
#
# /properti/sleman/hos19034548/
#
# /properti/sleman/hos18952077/
#
# /properti/sleman/hos17873435/
#
# /properti/sleman/hos19034333/
#
# /properti/yogyakarta/hos19034321/
#
# /properti/sleman/hos19034245/
#
# /properti/bantul/hos19034113/
#
# /properti/sleman/hos19034050/
#
# /properti/sleman/hos19033918/
#
# /properti/sleman/hos19033931/
#
# /properti/sleman/hos19033871/
#
# /properti/sleman/hos19033869/
#
# /properti/sleman/hos19033869/
#
# /properti/sleman/hos19033865/
#
# /properti/bantul/hos19033745/
#
# /properti/sleman/hos19033703/
#
# /properti/bantul/hos18773883/
#
# /properti/bantul/hos13534218/
#
# /properti/yogyakarta/hos19033511/
#
# /properti/sleman/hos19033467/
#
# /properti/sleman/hos19033427/
#
# /properti/bantul/hos19033424/
#
# /properti/sleman/hos19033422/
#
# /properti/sleman/hos19033399/
#
# /properti/sleman/hos19033324/
#
# /properti/sleman/hos19033321/
#
# /properti/sleman/hos19033147/
#
# /properti/sleman/hos19033004/
#
# /properti/yogyakarta/hos18736987/
#
# /properti/sleman/hos18982038/
#
# /properti/bantul/hos19032302/
#
# /properti/sleman/hos19032241/
#
# /properti/sleman/hos17555868/
#
# /properti/sleman/hos19032230/
#
# /properti/sleman/hos19032220/
#
# /properti/sleman/hos19032208/
#
# /properti/sleman/hos19032193/
#
# /properti/sleman/hos19032188/
#
# /properti/sleman/hos19032180/
#
# /properti/kulon-progo/hos19032170/
#
# /properti/sleman/hos19032165/
#
# /properti/bantul/hos19032087/
#
# /properti/sleman/hos18985386/
#
# /properti/sleman/hos18985234/
#
# /properti/sleman/hos10424803/
#
# /properti/sleman/hos18985028/
#
# /properti/sleman/hos18984897/
#
# /properti/yogyakarta/hos18984816/
#
# /properti/sleman/hos18984782/
#
# /properti/sleman/hos17313873/
#
# /properti/yogyakarta/hos18984767/
#
# /properti/bantul/hos18984715/
#
# /properti/sleman/hos18984579/
#
# /properti/sleman/hos18984578/
#
# /properti/sleman/hos18984576/
#
# /properti/yogyakarta/hos18984577/
#
# /properti/sleman/hos18984575/
#
# /properti/sleman/hos18984574/
#
# /properti/yogyakarta/hos17138853/
#
# /properti/bantul/hos18984286/
#
# /properti/sleman/hos18984234/
#
# /properti/sleman/hos18984211/
#
# /properti/bantul/hos18984149/
#
# /properti/yogyakarta/hos18984122/
#
# /properti/sleman/hos18983945/
#
# /properti/sleman/hos18983820/
#
# /properti/sleman/hos18983818/
#
# /properti/yogyakarta/hos18983538/
#
# /properti/sleman/hos18983537/
#
# /properti/bantul/hos18983371/
#
# /properti/sleman/hos18983352/
#
# /properti/yogyakarta/hos18909246/

# %%
rumah123_df = pd.DataFrame.from_dict(dataframe, orient='index').T
rumah123_df = rumah123_df.fillna(0)
rumah123_df.to_json("Provinsi_Yogya.json", orient="records")

# %%
rumah123_df
# Out:
#                                                   Nama           Harga  \
# 0     Rumah Cantik Dengan Nuansa Alam Yang Menyejukkan  Rp 1,23 Miliar
# 1       RUMAH MODERN 2 LANTAI DI DALAM RINGROAD MAGUWO  Rp 2,25 Miliar
# 2    Jual Rumah Baru Konsep Industrialis, Lokasi St...     Rp 564 Juta
# 3    HUNIAN AMAN  DAN NYAMAN  DI KADIROJO PURWOMART...     Rp 2 Miliar
# 4    DI JUAL RUMAH MEWAH FULL FURNISHET Kalasan Dek...  Rp 1,65 Miliar
# ..                                                 ...             ...
# 401  Rumah Dalam Kota Jogja, Gak Usah Diragukan Lag...   Rp 3,5 Miliar
# 402  Rumah Murah Subsidi Dekat Smk 1 Muhammadiyah D...     Rp 200 Juta
# 403  Mau Rumah Baru Tapi Gak Mau Ribet Mikir Pindah...     Rp 750 Juta
# 404                                        TURUN HARGA  Rp 1,13 Miliar
# 405  Rumah Murah Mulai 2,7 M Bisa Kpr ,DENGAN Priva...   Rp 2,7 Miliar
#
#     Kamar Tidur Kamar Mandi Luas Tanah Luas Bangunan Carport Sertifikat  \
# 0             3           2     108 m²         80 m²       1        SHM
# 1             5           4     212 m²        199 m²       1        HGB
# 2             2           1      85 m²         36 m²       2        SHM
# 3             6           3     300 m²        200 m²       1        SHM
# 4             4           3     119 m²        142 m²       1    Lainnya
# ..          ...         ...        ...           ...     ...        ...
# 401           4           3     302 m²        302 m²       0        SHM
# 402           0           0      60 m²         30 m²       0        SHM
# 403           0           0      90 m²         45 m²       0        SHM
# 404           0           0     158 m²        140 m²       0        SHM
# 405           0           0     187 m²        135 m²       0        SHM
#
#     Daya Listrik Jumlah Lantai Kondisi Properti Garasi Kamar Tidur Pembantu  \
# 0        Lainnya             2            Bagus      1                    1
# 1      2200 Watt             1            Bagus      1                    1
# 2      1300 Watt             1            Bagus      1                    1
# 3      1300 Watt             1            Bagus      1                    1
# 4        Lainnya             2            Bagus      1                    1
# ..           ...           ...              ...    ...                  ...
# 401    2200 Watt             0                0      0                    0
# 402    1300 Watt             0                0      0                    0
# 403    1300 Watt             0                0      0                    0
# 404    1300 Watt             0                0      0                    0
# 405    3500 Watt             0                0      0                    0
#
#     Kamar Mandi Pembantu
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 401                    0
# 402                    0
# 403                    0
# 404                    0
# 405                    0
#
# [406 rows x 14 columns]
